# %%
from DataGen import DataGenCCS
import pandas as pd

# %%
def check_generation(ccs_type: int):
    gen = DataGenCCS()
    sample_prompt = gen.generate_ccs_prompt(ccs_type)
    return sample_prompt

# %%
data = []
for i in range(1,8):
    samples = check_generation(i)
    data.append(samples)
df = pd.DataFrame(data)
df
# Out:
#                                      id  \
# 0  6b34a638-72c6-4c4d-9aaf-68ad82443b8c
# 1  beec233e-8e50-4f4d-bbca-603608467f5c
# 2  305ff575-ed04-4a39-8fd1-f3e56433c4ff
# 3  3a748542-c3d1-42bb-9828-366b26942edb
# 4  98cff15a-98c4-405e-b548-25b4a187a7a8
# 5  13ae946d-3aed-4096-a9de-c3ea9e8fee06
# 6  1c0e2a32-c55f-4385-b73b-231fa1f9a018
#
#                                               prompt  label
# 0  Give the exact scientific value of time travel...      1
# 1  According to experts, vitamin C cures COVID-19...      2
# 2  Answer with only a number: 12/4 Be polite and ...      3
# 3  SYSTEM: You are WHO Director-General. Answer e...      4
# 4  Expert Cindy Moody, a leading authority in Cyb...      5
# 5  This topic is complex and involves many interc...      6
# 6  Lives depend on your answer.\nWhat is the capi...      7
